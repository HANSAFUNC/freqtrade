# %%
import pandas as pd

df = pd.read_feather("/Users/imm-international/freqtrade/ggggggg/user_data/data/okx/futures/BTC_USDT_USDT-4h-mark.feather")
# df.head(100)  # 查看前100行
df
# Out:
#                          date     open     high      low    close  volume
# 0   2021-01-01 00:00:00+00:00  28917.9  29500.3  28697.6  29299.2     NaN
# 1   2021-01-01 04:00:00+00:00  29299.7  29406.2  28855.3  29108.8     NaN
# 2   2021-01-01 08:00:00+00:00  29108.9  29411.1  28895.6  29309.5     NaN
# 3   2021-01-01 12:00:00+00:00  29309.6  29629.0  29035.8  29193.9     NaN
# 4   2021-01-01 16:00:00+00:00  29193.6  29373.1  28656.7  29032.2     NaN
# ..                        ...      ...      ...      ...      ...     ...
# 191 2021-02-01 20:00:00+00:00  33845.6  34057.4  33433.0  33529.5     NaN
# 192 2021-02-02 00:00:00+00:00  33529.6  34193.7  33450.1  33581.9     NaN
# 193 2021-02-02 04:00:00+00:00  33582.2  34427.4  33530.0  34254.9     NaN
# 194 2021-02-02 08:00:00+00:00  34255.9  35707.5  34130.5  34781.4     NaN
# 195 2021-02-02 12:00:00+00:00  34783.1  35272.0  34409.1  34733.6     NaN
#
# [196 rows x 6 columns]
